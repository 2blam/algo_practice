# %% [markdown]
# A permutation of an array of integers is an arrangement of its members into a sequence or linear order.
#
# For example, for arr = [1,2,3], the following are considered permutations of arr: [1,2,3], [1,3,2], [3,1,2], [2,3,1].
# The next permutation of an array of integers is the next lexicographically greater permutation of its integer. More formally, if all the permutations of the array are sorted in one container according to their lexicographical order, then the next permutation of that array is the permutation that follows it in the sorted container. If such arrangement is not possible, the array must be rearranged as the lowest possible order (i.e., sorted in ascending order).
#
# For example, the next permutation of arr = [1,2,3] is [1,3,2].
# Similarly, the next permutation of arr = [2,3,1] is [3,1,2].
# While the next permutation of arr = [3,2,1] is [1,2,3] because [3,2,1] does not have a lexicographical larger rearrangement.
# Given an array of integers nums, find the next permutation of nums.
#
# The replacement must be in place and use only constant extra memory.
#
# Example 1:
#
# Input: nums = [1,2,3]
#
# Output: [1,3,2]
#
# Example 2:
#
# Input: nums = [3,2,1]
#
# Output: [1,2,3]
#
# Example 3:
#
# Input: nums = [1,1,5]
#
# Output: [1,5,1]
#
#
# Constraints:
#
# 1 <= nums.length <= 100
# 0 <= nums[i] <= 100

# %%
"""
   IDEA:
   suppose we have number 1 3 5 4 3 2 1
   1) find the longest, rightmost side, increasing sequence
      in this example: 1 3 5 4 3 2 1
                           ^ ^ ^ ^ ^
                           rightmost (r)
      Note: 
      if the rightmost position is 0, means the sequence are in max order
      we can reverse the nums and then return immediately
      Example: 3 2 1 ==> 1 2 3 (return)
      
   2) set the pivot point be the left one, i.e. 3
      in this example: 1 3 5 4 3 2 1
                         ^
                         pivot (p)

   3) scan the sequence that we found in step 1), from left to right, and find the num that just greater than the pivot
      in this example: 1 3 5 4 3 2 1
                         ^   ^
                         p   just greater (g)
   4) swap p and g
      in this example: 1 4 5 3 3 2 1
    
   5) reverse the suffix (from the pivot + 1 position)
      in this example: 1 4 5 3 3 2 1
                           ^ ^ ^ ^ ^
      after reverse:   1 4 1 2 3 3 5
"""
class Solution:
    def nextPermutation(self, nums) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        # step 1 - find the pivot
        rightmost = 0
        for i in range(len(nums)-1, 0, -1):
            if nums[i-1] < nums[i]:
                rightmost = i
                break
        
        # special case - max already
        if rightmost == 0:
            nums.sort()
            return
        pivot = rightmost -1
        # step 2 - get the item position that just greater than pivot
        for g in range(len(nums)-1, pivot, -1):
            if nums[g] > nums[pivot]:
                break
        # step 3 - swap

        nums[pivot], nums[g] = nums[g], nums[pivot]
        # step 4 - reverse the suffix from the pivot + 1 position
        nums[(pivot+1):] = reversed(nums[(pivot+1):])
        
# testing
l1 = [1, 3, 5, 4, 3, 2, 1]
Solution().nextPermutation(l1)
print(l1)

l2 = [3, 2, 1]
Solution().nextPermutation(l2)
print(l2)

l3 = [1,2]
Solution().nextPermutation(l3)
print(l3)
# Out:
# [1, 4, 1, 2, 3, 3, 5]
# [1, 2, 3]
# [2, 1]
